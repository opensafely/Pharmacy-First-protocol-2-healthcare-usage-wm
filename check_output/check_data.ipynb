# %%
import pandas as pd

# %%
df = pd.read_csv("../output/dataset.csv.gz")
df.head(10)
# Out:
#    patient_id has_pf_consultation       sex  age                    region  \
# 0           1                   F   unknown   34             East Midlands
# 1           2                   F    female   28             East Midlands
# 2           3                   F   unknown   63                North West
# 3           4                   F   unknown   15                North West
# 4           5                   F    female  113                North West
# 5           6                   F  intersex   33  Yorkshire and The Humber
# 6           7                   F      male   85                South East
# 7           8                   F   unknown   20                South West
# 8           9                   F   unknown   65                South West
# 9          10                   F    female   61                South East
#
#    imd_rounded  rural_urban
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# ...

# %%
df['rural_urban'].value_counts()
# Out:
# rural_urban
# 3.0    6
# 5.0    4
# 4.0    2
# 7.0    2
# 1.0    2
# 2.0    1
# Name: count, dtype: int64

# %%
df_practices = pd.read_csv("../output/dataset_practices.csv.gz")

df.head()
# Out:
#    patient_id has_pf_consultation       sex  age         region
# 0           1                   F      male   34  East Midlands
# 1           2                   F      male   28  East Midlands
# 2           3                   F      male   63     North West
# 3           4                   F      male   15     North West
# 4           5                   F  intersex  113     North West

# %%
df[df['has_pf_consultation']=='T']['region'].value_counts()
# Out:
# region
# Yorkshire and The Humber    11
# East                        10
# London                       8
# North West                   7
# West Midlands                6
# South West                   6
# East Midlands                5
# North East                   3
# South East                   2
# Name: count, dtype: int64

# %%
df_practices.head()
# Out:
#    patient_id has_pf_consultation      sex  age
# 0           1                   F  unknown   34
# 1           2                   F   female   28
# 2           3                   F     male   63
# 3           4                   F  unknown   15
# 4           5                   F   female  113

# %%
data_patients = pd.read_csv("../dummy-folder/patients.csv")
data_patients
# Out:
#      patient_id date_of_birth       sex
# 0             1    1991-10-01      male
# 1             2    1997-02-01      male
# 2             3    1962-11-01      male
# 3             4    2010-10-01      male
# 4             5    1912-05-01  intersex
# ..          ...           ...       ...
# 995         997    1970-06-01    female
# 996         998    1932-09-01    female
# 997         999    2009-09-01    female
# 998        1000    2024-12-01      male
# 999        1001    1911-07-01      male
#
# [1000 rows x 3 columns]

# %%
data_patients['sex'].value_counts()
# Out:
# sex
# male        378
# female      231
# intersex    209
# unknown     182
# Name: count, dtype: int64
